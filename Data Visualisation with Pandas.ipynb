# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  0.264616
# 2019-06-08 -0.049062
# 2019-06-09 -0.653870
# 2019-06-10  0.442041
# 2019-06-11 -0.031685

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.264616
# 2019-06-08  0.215554
# 2019-06-09 -0.438315
# 2019-06-10  0.003725
# 2019-06-11 -0.027960

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.860898
# 2019-06-08   -0.581376
# 2019-06-09    0.008253
# 2019-06-10    0.785477
# 2019-06-11    1.112539
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.922570  1.610052  1.485327  0.776849
# 1  1.294864  0.161840  0.436903 -0.330112
# 2  0.205705  1.141605 -0.043397 -0.294305
# 3 -1.280590  0.051089 -2.190617 -1.260673
# 4  0.817860  1.348544  0.978602 -0.723789
# 5 -1.219148 -0.842129 -1.071299  1.629489
# 6  0.827110  0.788430 -1.442376 -1.040704
# 7  0.274543  1.051475  0.855787  0.327379
# 8 -2.470190  0.342022  0.025257  1.265097
# 9  0.514749 -1.183795  0.332109  0.902690

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50)

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFDD419808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFDD447A48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFDD22C088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFDD261A88>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')
# df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', color = 'r')
df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE00A6A48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE00D4B08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE0233EC8>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 18, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE0A30408>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE0A5C2C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE0A8A788>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
plt.figure()

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True,figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE2FF70C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE30110C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE303ADC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CFE3075988>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-99-af09896ed1db> in <module>
# ----> 1 from descartes import PolygonPatch
#
# ModuleNotFoundError: No module named 'descartes'

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.7.0-py2.py3-none-any.whl (928 kB)
# Collecting shapely
#   Downloading Shapely-1.7.0-cp37-cp37m-win_amd64.whl (1.0 MB)
# Collecting fiona
#   Downloading Fiona-1.8.13.post1.tar.gz (1.2 MB)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\SHRUTI~1\\AppData\\Local\\Temp\\pip-install-pcoif_1w\\fiona\\setup.py'"'"'; __file__='"'"'C:\\Users\\SHRUTI~1\\AppData\\Local\\Temp\\pip-install-pcoif_1w\\fiona\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\SHRUTI~1\AppData\Local\Temp\pip-install-pcoif_1w\fiona\pip-egg-info'
#          cwd: C:\Users\SHRUTI~1\AppData\Local\Temp\pip-install-pcoif_1w\fiona\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-e5267478385a> in <module>
# ----> 1 map_df = pd.read_file("London_Borough_Excluding_MHW.shp")
#       2 # check data type so we can see that this is not a normal dataframe, but a GEOdataframe
#       3 map_df.head()
#       4 map_df.plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'read_file'

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# 12                Lewisham  E09000023   3531.706      16.795         T
# 13               Greenwich  E09000011   5044.190     310.785         F
# 14                  Bexley  E09000004   6428.649     370.619         F
# 15                 Enfield  E09000010   8220.025       0.000         F
# 16          Waltham Forest  E09000031   3880.793       0.000         F
# 17               Redbridge  E09000026   5644.225       2.300         F
# 18                  Sutton  E09000029   4384.698       0.000         F
# 19    Richmond upon Thames  E09000027   5876.111     135.443         F
# 20                  Merton  E09000024   3762.466       0.000         F
# 21              Wandsworth  E09000032   3522.022      95.600         T
# 22  Hammersmith and Fulham  E09000013   1715.409      75.648         T
# 23  Kensington and Chelsea  E09000020   1238.379      25.994         T
# 24             Westminster  E09000033   2203.005      54.308         T
# 25                  Camden  E09000007   2178.932       0.000         T
# 26           Tower Hamlets  E09000030   2157.501     179.707         T
# 27               Islington  E09000019   1485.664       0.000         T
# 28                 Hackney  E09000012   1904.902       0.000         T
# 29                Haringey  E09000014   2959.837       0.000         T
# 30                  Newham  E09000025   3857.806     237.637         T
# 31    Barking and Dagenham  E09000002   3779.934     169.150         F
# 32          City of London  E09000001    314.942      24.546         T
#
#    SUB_2009 SUB_2006                                           geometry
# 0      None     None  POLYGON ((516401.6 160201.8, 516407.3 160210.5...
# 1      None     None  POLYGON ((535009.2 159504.7, 535005.5 159502, ...
# 2      None     None  POLYGON ((540373.6 157530.4, 540361.2 157551.9...
# 3      None     None  POLYGON ((521975.8 178100, 521967.7 178096.8, ...
# 4      None     None  POLYGON ((510253.5 182881.6, 510249.9 182886, ...
# 5      None     None  POLYGON ((549893.9 181459.8, 549894.6 181465.7...
# 6      None     None  POLYGON ((510599.8 191689.5, 510615.2 191591.3...
# 7      None     None  POLYGON ((510599.8 191689.5, 510660 191690.9, ...
# 8      None     None  POLYGON ((525201 182512.6, 525181.5 182521.1, ...
# 9      None     None  POLYGON ((524579.9 198355.2, 524594.3 198321.4...
# 10     None     None  POLYGON ((530046.8 177893.4, 530048.4 177894.6...
# 11     None     None  POLYGON ((531335.6 180529.5, 531337.7 180530.5...
# 12     None     None  POLYGON ((536691 178958.6, 536691.9 178955.3, ...
# 13     None     None  (POLYGON ((537238.7 178137.7, 537242.6 178136....
# 14     None     None  POLYGON ((547226.2 181299.3, 547320.9 181342.4...
# 15     None     None  POLYGON ((531023.5 200933.6, 531039.9 200933.9...
# 16     None     None  POLYGON ((539923.1 191863.1, 539928.1 191846.6...
# 17     None     None  POLYGON ((543595.5 184832.8, 543577.1 184837.7...
# 18     None     None  POLYGON ((528552.3 159658.1, 528399.7 159928.8...
# 19     None     None  POLYGON ((516677.5 175383.8, 516678.6 175378.9...
# 20     None     None  POLYGON ((529906.2 167417.3, 529902.2 167411.8...
# 21     None     None  POLYGON ((523489.6 176224.8, 523500.6 176218.4...
# 22     None     None  POLYGON ((521975.8 178100, 521973 178109.8, 52...
# 23     None     None  POLYGON ((526219.7 176948, 526208.8 176960.4, ...
# 24     None     None  POLYGON ((528549.5 177903.8, 528542.6 177949.4...
# 25     None     None  POLYGON ((528840.2 187217.8, 528834.6 187205.8...
# 26     None     None  POLYGON ((533387.6 180516.4, 533389.8 180523.6...
# 27     None     None  POLYGON ((529153.6 185861.4, 529144.8 185877.8...
# 28     None     None  POLYGON ((531928.4 187801.5, 531935.7 187804.4...
# 29     None     None  POLYGON ((531928.4 187801.5, 531919.2 187797.3...
# 30     None     None  (POLYGON ((544065 183254.1, 544062.9 183259, 5...
# 31     None     None  (POLYGON ((543905.4 183199.1, 543905 183198.9,...
# 32     None     None  POLYGON ((531145.1 180782.1, 531143.8 180799.3...
